# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
# os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/My Drive/Kaggle/mask_image"
# %cd /content/gdrive/My Drive/Kaggle
# !kaggle datasets download -d saketjajoo/maskedlfw
# !unzip \maskedlfw.zip  && rm maskedlfw.zip
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
from tensorflow import keras

# training set
train_datagen = keras.preprocessing.image.ImageDataGenerator(rescale=1/255
                                                             )
train_generator = train_datagen.flow_from_directory(
    "/content/gdrive/MyDrive/Kaggle/masked", 
    target_size=(250,250), 
    batch_size=32, 
    class_mode='categorical'
) 

# test set

test_datagen = keras.preprocessing.image.ImageDataGenerator(rescale=1/255)

test_generator = test_datagen.flow_from_directory(
    '/content/gdrive/MyDrive/Kaggle/test', 
    target_size=(250,250), 
    batch_size=32, 
    class_mode='categorical'
)
# Out:
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.

# %%
print(train_generator[0][0].shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-fa5f5f771ef3> in <module>()
#       1
# ----> 2 print(train_generator[0][0].shape)
#
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/iterator.py in __getitem__(self, idx)
#      55                              'but the Sequence '
#      56                              'has length {length}'.format(idx=idx,
# ---> 57                                                           length=len(self)))
#      58         if self.seed is not None:
#      59             np.random.seed(self.seed + self.total_batches_seen)
#
# ValueError: Asked to retrieve element 0, but the Sequence has length 0

# %%
from tensorflow import keras

model = keras.Sequential()
model.add(keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=train_generator.image_shape))
model.add(keras.layers.Conv2D(32, (3,3), activation='relu'))
model.add(keras.layers.MaxPool2D(pool_size=(2,2)))
model.add(keras.layers.Dropout(0.2))
model.add(keras.layers.Conv2D(32, (3,3), activation='relu'))
model.add(keras.layers.Conv2D(32, (3,3), activation='relu'))
model.add(keras.layers.MaxPool2D(pool_size=(2,2)))
model.add(keras.layers.Dropout(0.2))
model.add(keras.layers.Conv2D(32, (3,3), activation='relu'))
model.add(keras.layers.Conv2D(32, (3,3), activation='relu'))
model.add(keras.layers.MaxPool2D(pool_size=(2,2)))
model.add(keras.layers.Dropout(0.2))
model.add(keras.layers.Conv2D(32, (3,3), activation='relu'))
model.add(keras.layers.Conv2D(32, (3,3), activation='relu'))
model.add(keras.layers.MaxPool2D(pool_size=(2,2)))
model.add(keras.layers.Dropout(0.2))
model.add(keras.layers.Conv2D(32, (3,3), activation='relu'))
model.add(keras.layers.Conv2D(32, (3,3), activation='relu'))
model.add(keras.layers.MaxPool2D(pool_size=(2,2)))
model.add(keras.layers.Dropout(0.2))


model.add(keras.layers.Flatten())

model.add(keras.layers.Dense(128, activation='relu'))
model.add(keras.layers.Dense(64, activation='relu'))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(5, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_10 (Conv2D)           (None, 254, 254, 32)      896
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 252, 252, 32)      9248
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 126, 126, 32)      0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 126, 126, 32)      0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 124, 124, 32)      9248
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 122, 122, 32)      9248
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 61, 61, 32)        0
# ...

# %%
# 5. compile

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# 6. train
# from keras.callbacks import EarlyStopping

epochs = 10

es = keras.callbacks.EarlyStopping(monitor='val_acc', mode='max', verbose=1, patience=10)

history = model.fit(train_generator, 
                    steps_per_epoch=30, # 총 학습 이미지 개수 / 배치 사이즈 
                    epochs=epochs,
                    validation_data=test_generator,
                    validation_steps=8,
                    callbacks=[es]
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-22bf7b1648af> in <module>()
#      11                     validation_data=test_generator,
#      12                     validation_steps=8,
# ---> 13                     callbacks=[es]
#      14 )
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1145           use_multiprocessing=use_multiprocessing,
#    1146           model=self,
# -> 1147           steps_per_execution=self._steps_per_execution)
#    1148
#    1149       # Container that configures and calls `tf.keras.Callback`s.
#
# ...
